# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering
from sklearn.manifold import MDS

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Lettura del data set; selezione delle colonne

# %%
df = pd.read_csv(
    '/content/drive/MyDrive/Data Science Lab/WVS_Cross-National_Wave_7_csv_v6_0.csv')
df
# Out:
# <ipython-input-3-255de0e0a005>:1: DtypeWarning: Columns (346,348,350,580,581,582,583) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#                   version                        doi  A_WAVE  A_YEAR  A_STUDY  \
# 0      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 1      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 2      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 3      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# 4      6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2018        2
# ...                   ...                        ...     ...     ...      ...
# 97215  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
# 97216  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
# 97217  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
# 97218  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
# 97219  6-0-0 (2024-04-30)  doi.org/10.14281/18241.24       7    2020        2
#
#        B_COUNTRY B_COUNTRY_ALPHA  C_COW_NUM C_COW_ALPHA  D_INTERVIEW  ...  \
# 0             20             AND        232         AND     20070001  ...
# 1             20             AND        232         AND     20070002  ...
# 2             20             AND        232         AND     20070003  ...
# 3             20             AND        232         AND     20070004  ...
# 4             20             AND        232         AND     20070005  ...
# ...          ...             ...        ...         ...          ...  ...
# 97215        716             ZWE        552         ZIM    716071211  ...
# 97216        716             ZWE        552         ZIM    716071212  ...
# 97217        716             ZWE        552         ZIM    716071213  ...
# 97218        716             ZWE        552         ZIM    716071214  ...
# 97219        716             ZWE        552         ZIM    716071215  ...
#
#        WVS_Polmistrust_PartyVoter  WVS_LR_MedianVoter  WVS_LibCon_MedianVoter  \
# 0                       62.434211              -999.0                  -999.0
# 1                       62.434211              -999.0                  -999.0
# 2                       62.434211              -999.0                  -999.0
# 3                             NaN                 NaN                     NaN
# 4                       66.964286              -999.0                  -999.0
# ...                           ...                 ...                     ...
# 97215                         NaN                 NaN                     NaN
# 97216                         NaN                 NaN                     NaN
# 97217                         NaN                 NaN                     NaN
# 97218                         NaN                 NaN                     NaN
# 97219                         NaN                 NaN                     NaN
#
#        v2psbars  v2psorgs  v2psprbrch  v2psprlnks  v2psplats  v2xnp_client  \
# 0        -999.0    -999.0      -999.0      -999.0     -999.0        -999.0
# 1        -999.0    -999.0      -999.0      -999.0     -999.0        -999.0
# 2        -999.0    -999.0      -999.0      -999.0     -999.0        -999.0
# 3           NaN       NaN         NaN         NaN        NaN           NaN
# 4        -999.0    -999.0      -999.0      -999.0     -999.0        -999.0
# ...         ...       ...         ...         ...        ...           ...
# 97215       NaN       NaN         NaN         NaN        NaN           NaN
# 97216       NaN       NaN         NaN         NaN        NaN           NaN
# 97217       NaN       NaN         NaN         NaN        NaN           NaN
# 97218       NaN       NaN         NaN         NaN        NaN           NaN
# 97219       NaN       NaN         NaN         NaN        NaN           NaN
#
#        v2xps_party
# 0           -999.0
# 1           -999.0
# 2           -999.0
# 3              NaN
# 4           -999.0
# ...            ...
# 97215          NaN
# 97216          NaN
# 97217          NaN
# 97218          NaN
# 97219          NaN
#
# [97220 rows x 613 columns]

# %%
df1 = df.iloc[:, [6] + list(range(424, 456))]
df1
# Out:
#       B_COUNTRY_ALPHA  I_AUTHORITY  I_NATIONALISM  I_DEVOUT  DEFIANCE  \
# 0                 AND          0.0            NaN      0.66  0.382580
# 1                 AND          0.0           0.00      0.66  0.220000
# 2                 AND          0.0           0.66      0.66  0.440000
# 3                 AND          0.5            NaN      0.66  0.574580
# 4                 AND          0.5            NaN      0.66  0.574580
# ...               ...          ...            ...       ...       ...
# 97215             ZWE          0.0           0.00      0.00  0.000000
# 97216             ZWE          0.0           1.00      0.00  0.333333
# 97217             ZWE          0.0           0.00      0.00  0.000000
# 97218             ZWE          0.0           0.33      0.33  0.220000
# 97219             ZWE          0.0           0.33      0.00  0.110000
#
#        I_RELIGIMP  I_RELIGBEL  I_RELIGPRAC  DISBELIEF  I_NORM1  ...  I_WOMEDU  \
# 0            1.00         0.0     1.000000   0.666667      0.0  ...      0.66
# 1            1.00         1.0     1.000000   1.000000      0.0  ...      0.66
# 2            0.66         1.0     1.000000   0.886667      0.0  ...      0.66
# 3            1.00         1.0     1.000000   1.000000      0.0  ...      1.00
# 4            0.66         1.0     1.000000   0.886667      0.0  ...      0.66
# ...           ...         ...          ...        ...      ...  ...       ...
# 97215        0.33         0.0     0.166667   0.165556      1.0  ...      0.66
# 97216        0.00         0.0     0.000000   0.000000      0.0  ...      1.00
# 97217        0.33         0.0     0.333333   0.221111      0.0  ...      0.66
# 97218        0.00         0.0     0.166667   0.055556      0.0  ...      0.66
# 97219        0.00         0.0     0.166667   0.055556      0.0  ...      0.66
#
#        EQUALITY  I_HOMOLIB  I_ABORTLIB  I_DIVORLIB    CHOICE  I_VOICE1  \
# 0      0.690000   0.333333    0.111111    0.444444  0.296296      0.00
# 1      0.690000   0.888889    0.888889    0.888889  0.888889      1.00
# 2      0.690000   1.000000    0.444444    0.555556  0.666667      0.33
# 3      0.916667   0.555556    0.333333    0.888889  0.592593      0.33
# 4      0.690000   0.777778    0.444444    0.666667  0.629630      0.00
# ...         ...        ...         ...         ...       ...       ...
# 97215  0.220000   0.000000    0.000000    0.000000  0.000000      0.66
# 97216  0.666667   0.000000    0.000000    0.777778  0.259259      1.00
# 97217  0.690000   0.000000    0.000000    0.000000  0.000000      0.33
# 97218  0.690000   0.000000    0.000000    0.000000  0.000000      0.00
# 97219  0.523333   0.000000    0.000000    0.000000  0.000000      0.00
#
#        I_VOICE2  I_VOI2_00  VOICE
# 0           0.0      0.000  0.000
# 1           0.0      0.500  0.500
# 2           0.5      0.415  0.415
# 3           0.5      0.415  0.415
# 4           0.5      0.250  0.250
# ...         ...        ...    ...
# 97215       0.5      0.580  0.580
# 97216       0.0      0.500  0.500
# 97217       0.0      0.165  0.165
# 97218       0.0      0.000  0.000
# 97219       0.0      0.000  0.000
#
# [97220 rows x 33 columns]

# %% [markdown]
# # Pulizia: rimpiazzo di "MAC" (Macau) con "CHN" (Cina), e di "NIR" (Irlanda del Nord) con "GBR" (Regno Unito)

# %%
df1['B_COUNTRY_ALPHA'].unique()
# Out:
# array(['AND', 'ARG', 'ARM', 'AUS', 'BGD', 'BOL', 'BRA', 'CAN', 'CHL',
#        'CHN', 'COL', 'CYP', 'CZE', 'DEU', 'ECU', 'EGY', 'ETH', 'GBR',
#        'GRC', 'GTM', 'HKG', 'IDN', 'IND', 'IRN', 'IRQ', 'JOR', 'JPN',
#        'KAZ', 'KEN', 'KGZ', 'KOR', 'LBN', 'LBY', 'MAC', 'MAR', 'MDV',
#        'MEX', 'MMR', 'MNG', 'MYS', 'NGA', 'NIC', 'NIR', 'NLD', 'NZL',
#        'PAK', 'PER', 'PHL', 'PRI', 'ROU', 'RUS', 'SGP', 'SRB', 'SVK',
#        'THA', 'TJK', 'TUN', 'TUR', 'TWN', 'UKR', 'URY', 'USA', 'UZB',
#        'VEN', 'VNM', 'ZWE'], dtype=object)

# %%
df1['B_COUNTRY_ALPHA'].replace(
    to_replace={'MAC': 'CHN', 'NIR': 'GBR'}, inplace=True)
# Out:
# <ipython-input-6-70bbf0a57172>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['B_COUNTRY_ALPHA'].replace(

# %% [markdown]
# # Statistiche descrittive; rimozione dei record incompleti (da 97220 a 89494 record); istogrammi; correlazioni; distribuzione degli intervistati per paese (grafico a barre)

# %%
df1.describe(include='all')
# Out:
#        B_COUNTRY_ALPHA   I_AUTHORITY  I_NATIONALISM      I_DEVOUT  \
# count            97220  94496.000000   94132.000000  95544.000000
# unique              64           NaN            NaN           NaN
# top                CHN           NaN            NaN           NaN
# freq              4059           NaN            NaN           NaN
# mean               NaN      0.287811       0.180968      0.215316
# std                NaN      0.374153       0.247577      0.246482
# min                NaN      0.000000       0.000000      0.000000
# 25%                NaN      0.000000       0.000000      0.000000
# 50%                NaN      0.000000       0.000000      0.330000
# 75%                NaN      0.500000       0.330000      0.330000
# max                NaN      1.000000       1.000000      1.000000
#
#             DEFIANCE    I_RELIGIMP    I_RELIGBEL   I_RELIGPRAC     DISBELIEF  \
# count   96653.000000  96294.000000  94568.000000  96008.000000  96520.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.232894      0.327671      0.383872      0.533077      0.416716
# std         0.199394      0.364166      0.486330      0.365959      0.337187
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.110000      0.000000      0.000000      0.166667      0.111111
# 50%         0.220000      0.330000      0.000000      0.500000      0.333333
# 75%         0.386667      0.660000      1.000000      1.000000      0.720000
# max         1.000000      1.000000      1.000000      1.000000      1.014000
#
#              I_NORM1  ...      I_WOMEDU      EQUALITY     I_HOMOLIB  \
# count   93681.000000  ...  95792.000000  96342.000000  89705.000000
# unique           NaN  ...           NaN           NaN           NaN
# top              NaN  ...           NaN           NaN           NaN
# freq             NaN  ...           NaN           NaN           NaN
# mean        0.484111  ...      0.666989      0.576234      0.339097
# std         0.499750  ...      0.301188      0.257771      0.378684
# min         0.000000  ...      0.000000      0.000000      0.000000
# 25%         0.000000  ...      0.660000      0.413333      0.000000
# 50%         0.000000  ...      0.660000      0.606667      0.222222
# 75%         1.000000  ...      1.000000      0.750000      0.666667
# max         1.000000  ...      1.000000      1.000000      1.000000
#
#           I_ABORTLIB    I_DIVORLIB        CHOICE      I_VOICE1      I_VOICE2  \
# count   94945.000000  95291.000000  95255.000000  94078.000000  92940.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.283798      0.445251      0.353275      0.385355      0.349021
# std         0.332093      0.355807      0.303081      0.324892      0.396206
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.074074      0.000000      0.000000
# 50%         0.111111      0.444444      0.296296      0.330000      0.000000
# 75%         0.444444      0.777778      0.555556      0.660000      0.500000
# max         1.000000      1.000000      1.000000      1.000000      1.000000
#
#            I_VOI2_00         VOICE
# count   91841.000000  95206.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        0.366866      0.367562
# std         0.286456      0.284618
# min         0.000000      0.000000
# 25%         0.165000      0.165000
# 50%         0.330000      0.330000
# 75%         0.580000      0.580000
# max         1.000000      1.000000
#
# [11 rows x 33 columns]

# %%
df1.dropna(
    subset=[
        'DEFIANCE', 'DISBELIEF', 'RELATIVISM', 'SCEPTICISM', 'AUTONOMY',
        'EQUALITY', 'CHOICE', 'VOICE'],
    inplace=True)
df1.size
# Out:
# <ipython-input-8-6f0c43785a71>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(
# 2953302

# %%
indexes = df1.iloc[:, [0, 4, 8, 12, 16, 20, 24, 28, 32]]
indexes
# Out:
#       B_COUNTRY_ALPHA  DEFIANCE  DISBELIEF  RELATIVISM  SCEPTICISM  AUTONOMY  \
# 0                 AND  0.382580   0.666667         0.0    0.099000  0.666667
# 1                 AND  0.220000   1.000000         0.0    0.650100  0.000000
# 2                 AND  0.440000   0.886667         0.0    0.374550  1.000000
# 3                 AND  0.574580   1.000000         0.0    0.650100  0.000000
# 4                 AND  0.574580   0.886667         0.0    0.374550  0.333333
# ...               ...       ...        ...         ...         ...       ...
# 97215             ZWE  0.000000   0.165556         1.0    0.000000  0.666667
# 97216             ZWE  0.333333   0.000000         0.0    0.773333  0.333333
# 97217             ZWE  0.000000   0.221111         0.0    0.550000  0.000000
# 97218             ZWE  0.220000   0.055556         0.0    0.330000  0.666667
# 97219             ZWE  0.110000   0.055556         0.0    0.660000  0.000000
#
#        EQUALITY    CHOICE  VOICE
# 0      0.690000  0.296296  0.000
# 1      0.690000  0.888889  0.500
# 2      0.690000  0.666667  0.415
# 3      0.916667  0.592593  0.415
# 4      0.690000  0.629630  0.250
# ...         ...       ...    ...
# 97215  0.220000  0.000000  0.580
# 97216  0.666667  0.259259  0.500
# 97217  0.690000  0.000000  0.165
# 97218  0.690000  0.000000  0.000
# 97219  0.523333  0.000000  0.000
#
# [89494 rows x 9 columns]

# %%
indexes.hist(sharey=True)
plt.tight_layout()

# %%
(indexes.corr(numeric_only=True)
 .style.background_gradient(cmap='RdBu', axis=None, vmin=-1, vmax=1))
# Out:
# <style type="text/css">
# #T_bbb6f_row0_col0, #T_bbb6f_row1_col1, #T_bbb6f_row2_col2, #T_bbb6f_row3_col3, #T_bbb6f_row4_col4, #T_bbb6f_row5_col5, #T_bbb6f_row6_col6, #T_bbb6f_row7_col7 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_bbb6f_row0_col1, #T_bbb6f_row1_col0 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_bbb6f_row0_col2, #T_bbb6f_row2_col0, #T_bbb6f_row3_col5, #T_bbb6f_row5_col3 {
#   background-color: #e1edf3;
#   color: #000000;
# }
# #T_bbb6f_row0_col3, #T_bbb6f_row3_col0 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_bbb6f_row0_col4, #T_bbb6f_row4_col0 {
#   background-color: #c7e0ed;
#   color: #000000;
# }
# #T_bbb6f_row0_col5, #T_bbb6f_row5_col0 {
#   background-color: #d2e6f0;
#   color: #000000;
# }
# #T_bbb6f_row0_col6, #T_bbb6f_row6_col0 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_bbb6f_row0_col7, #T_bbb6f_row7_col0 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_bbb6f_row1_col2, #T_bbb6f_row2_col1 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_bbb6f_row1_col3, #T_bbb6f_row3_col1 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_bbb6f_row1_col4, #T_bbb6f_row4_col1 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_bbb6f_row1_col5, #T_bbb6f_row5_col1 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_bbb6f_row1_col6, #T_bbb6f_row6_col1 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_bbb6f_row1_col7, #T_bbb6f_row3_col7, #T_bbb6f_row7_col1, #T_bbb6f_row7_col3 {
#   background-color: #e3edf3;
#   color: #000000;
# }
# #T_bbb6f_row2_col3, #T_bbb6f_row3_col2 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_bbb6f_row2_col4, #T_bbb6f_row2_col7, #T_bbb6f_row4_col2, #T_bbb6f_row7_col2 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_bbb6f_row2_col5, #T_bbb6f_row5_col2 {
#   background-color: #f9ede5;
#   color: #000000;
# }
# #T_bbb6f_row2_col6, #T_bbb6f_row6_col2 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_bbb6f_row3_col4, #T_bbb6f_row4_col3 {
#   background-color: #f9eee7;
#   color: #000000;
# }
# #T_bbb6f_row3_col6, #T_bbb6f_row6_col3 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_bbb6f_row4_col5, #T_bbb6f_row5_col4 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_bbb6f_row4_col6, #T_bbb6f_row6_col4 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_bbb6f_row4_col7, #T_bbb6f_row7_col4 {
#   background-color: #e6eff4;
#   color: #000000;
# }
# #T_bbb6f_row5_col6, #T_bbb6f_row6_col5 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_bbb6f_row5_col7, #T_bbb6f_row7_col5 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_bbb6f_row6_col7, #T_bbb6f_row7_col6 {
#   background-color: #cce2ef;
#   color: #000000;
# }
# </style>
# <table id="T_bbb6f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbb6f_level0_col0" class="col_heading level0 col0" >DEFIANCE</th>
#       <th id="T_bbb6f_level0_col1" class="col_heading level0 col1" >DISBELIEF</th>
#       <th id="T_bbb6f_level0_col2" class="col_heading level0 col2" >RELATIVISM</th>
#       <th id="T_bbb6f_level0_col3" class="col_heading level0 col3" >SCEPTICISM</th>
#       <th id="T_bbb6f_level0_col4" class="col_heading level0 col4" >AUTONOMY</th>
#       <th id="T_bbb6f_level0_col5" class="col_heading level0 col5" >EQUALITY</th>
#       <th id="T_bbb6f_level0_col6" class="col_heading level0 col6" >CHOICE</th>
#       <th id="T_bbb6f_level0_col7" class="col_heading level0 col7" >VOICE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbb6f_level0_row0" class="row_heading level0 row0" >DEFIANCE</th>
#       <td id="T_bbb6f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bbb6f_row0_col1" class="data row0 col1" >0.356724</td>
#       <td id="T_bbb6f_row0_col2" class="data row0 col2" >0.113541</td>
#       <td id="T_bbb6f_row0_col3" class="data row0 col3" >0.126068</td>
#       <td id="T_bbb6f_row0_col4" class="data row0 col4" >0.233453</td>
#       <td id="T_bbb6f_row0_col5" class="data row0 col5" >0.188164</td>
#       <td id="T_bbb6f_row0_col6" class="data row0 col6" >0.291528</td>
#       <td id="T_bbb6f_row0_col7" class="data row0 col7" >0.147851</td>
#     </tr>
#     <tr>
#       <th id="T_bbb6f_level0_row1" class="row_heading level0 row1" >DISBELIEF</th>
#       <td id="T_bbb6f_row1_col0" class="data row1 col0" >0.356724</td>
#       <td id="T_bbb6f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bbb6f_row1_col2" class="data row1 col2" >0.077564</td>
#       <td id="T_bbb6f_row1_col3" class="data row1 col3" >0.022953</td>
#       <td id="T_bbb6f_row1_col4" class="data row1 col4" >0.257693</td>
#       <td id="T_bbb6f_row1_col5" class="data row1 col5" >0.274807</td>
#       <td id="T_bbb6f_row1_col6" class="data row1 col6" >0.450225</td>
#       <td id="T_bbb6f_row1_col7" class="data row1 col7" >0.102099</td>
#     </tr>
#     <tr>
#       <th id="T_bbb6f_level0_row2" class="row_heading level0 row2" >RELATIVISM</th>
#       <td id="T_bbb6f_row2_col0" class="data row2 col0" >0.113541</td>
#       <td id="T_bbb6f_row2_col1" class="data row2 col1" >0.077564</td>
#       <td id="T_bbb6f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_bbb6f_row2_col3" class="data row2 col3" >0.063780</td>
#       <td id="T_bbb6f_row2_col4" class="data row2 col4" >0.051046</td>
#       <td id="T_bbb6f_row2_col5" class="data row2 col5" >-0.077122</td>
#       <td id="T_bbb6f_row2_col6" class="data row2 col6" >0.199195</td>
#       <td id="T_bbb6f_row2_col7" class="data row2 col7" >0.048962</td>
#     </tr>
#     <tr>
#       <th id="T_bbb6f_level0_row3" class="row_heading level0 row3" >SCEPTICISM</th>
#       <td id="T_bbb6f_row3_col0" class="data row3 col0" >0.126068</td>
#       <td id="T_bbb6f_row3_col1" class="data row3 col1" >0.022953</td>
#       <td id="T_bbb6f_row3_col2" class="data row3 col2" >0.063780</td>
#       <td id="T_bbb6f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_bbb6f_row3_col4" class="data row3 col4" >-0.062508</td>
#       <td id="T_bbb6f_row3_col5" class="data row3 col5" >0.117045</td>
#       <td id="T_bbb6f_row3_col6" class="data row3 col6" >0.036437</td>
#       <td id="T_bbb6f_row3_col7" class="data row3 col7" >0.101941</td>
#     </tr>
#     <tr>
#       <th id="T_bbb6f_level0_row4" class="row_heading level0 row4" >AUTONOMY</th>
#       <td id="T_bbb6f_row4_col0" class="data row4 col0" >0.233453</td>
#       <td id="T_bbb6f_row4_col1" class="data row4 col1" >0.257693</td>
#       <td id="T_bbb6f_row4_col2" class="data row4 col2" >0.051046</td>
#       <td id="T_bbb6f_row4_col3" class="data row4 col3" >-0.062508</td>
#       <td id="T_bbb6f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_bbb6f_row4_col5" class="data row4 col5" >0.121718</td>
#       <td id="T_bbb6f_row4_col6" class="data row4 col6" >0.209328</td>
#       <td id="T_bbb6f_row4_col7" class="data row4 col7" >0.091553</td>
#     </tr>
#     <tr>
#       <th id="T_bbb6f_level0_row5" class="row_heading level0 row5" >EQUALITY</th>
#       <td id="T_bbb6f_row5_col0" class="data row5 col0" >0.188164</td>
#       <td id="T_bbb6f_row5_col1" class="data row5 col1" >0.274807</td>
#       <td id="T_bbb6f_row5_col2" class="data row5 col2" >-0.077122</td>
#       <td id="T_bbb6f_row5_col3" class="data row5 col3" >0.117045</td>
#       <td id="T_bbb6f_row5_col4" class="data row5 col4" >0.121718</td>
#       <td id="T_bbb6f_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_bbb6f_row5_col6" class="data row5 col6" >0.422511</td>
#       <td id="T_bbb6f_row5_col7" class="data row5 col7" >0.186746</td>
#     </tr>
#     <tr>
#       <th id="T_bbb6f_level0_row6" class="row_heading level0 row6" >CHOICE</th>
#       <td id="T_bbb6f_row6_col0" class="data row6 col0" >0.291528</td>
#       <td id="T_bbb6f_row6_col1" class="data row6 col1" >0.450225</td>
#       <td id="T_bbb6f_row6_col2" class="data row6 col2" >0.199195</td>
#       <td id="T_bbb6f_row6_col3" class="data row6 col3" >0.036437</td>
#       <td id="T_bbb6f_row6_col4" class="data row6 col4" >0.209328</td>
#       <td id="T_bbb6f_row6_col5" class="data row6 col5" >0.422511</td>
#       <td id="T_bbb6f_row6_col6" class="data row6 col6" >1.0

# %%
(indexes['B_COUNTRY_ALPHA'].value_counts(ascending=True)
 .plot.barh(figsize=(6, 8)))
plt.tight_layout()

# %% [markdown]
# # Indici medi per paese ("mean_indexes")

# %%
mean_indexes = indexes.groupby(by='B_COUNTRY_ALPHA').mean()
mean_indexes
# Out:
#                  DEFIANCE  DISBELIEF  RELATIVISM  SCEPTICISM  AUTONOMY  \
# B_COUNTRY_ALPHA
# AND              0.317477   0.667209    0.219285    0.448804  0.470808
# ARG              0.232448   0.465384    0.387223    0.646421  0.422446
# ARM              0.117089   0.315006    0.116716    0.518320  0.354184
# AUS              0.262710   0.669868    0.309231    0.339224  0.565234
# BGD              0.084851   0.134763    0.364076    0.357076  0.425847
# ...                   ...        ...         ...         ...       ...
# USA              0.292283   0.495941    0.419456    0.385974  0.565681
# UZB              0.106755   0.390307    0.476516    0.221915  0.538188
# VEN              0.133942   0.408977    0.396919    0.735165  0.277871
# VNM              0.135717   0.638662    0.653738    0.267428  0.376335
# ZWE              0.124523   0.102842    0.212187    0.490761  0.276766
#
#                  EQUALITY    CHOICE     VOICE
# B_COUNTRY_ALPHA
# AND              0.821144  0.716493  0.497649
# ARG              0.701435  0.486628  0.371500
# ARM              0.540881  0.167118  0.160574
# AUS              0.818340  0.693670  0.464546
# BGD              0.386657  0.107031  0.299406
# ...                   ...       ...       ...
# USA              0.723078  0.562686  0.459695
# UZB              0.346207  0.217257  0.400038
# VEN              0.658154  0.353688  0.349197
# VNM              0.496048  0.446349  0.310514
# ZWE              0.574300  0.119331  0.286254
#
# [63 rows x 8 columns]

# %% [markdown]
# # Clustering gerarchico dei paesi ("mean_indexes"), dendrogramma del clustering (9 cluster scegliendo 0.7 come distanza massima); aggiunta della colonna "cluster" delle etichette (0, 1, ..., 8) a "mean_indexes"

# %%
clustering = AgglomerativeClustering(n_clusters=None, distance_threshold=0.7)
clustering = clustering.fit(mean_indexes)
mean_indexes['cluster'] = clustering.labels_

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)['leaves_color_list']

# %%
plt.figure(figsize=(4.8, 6.4))
plot_dendrogram(
    clustering, color_threshold=0.7, orientation='right',
    labels=list(zip(mean_indexes['cluster'], mean_indexes.index)))
plt.tight_layout()

# %% [markdown]
# # Caricamento e join del data set integrativo "cartel1" da incrociare con il clustering ottenuto; colonne utili: "Continent" (categorica), "RegimeType2022" (categorica), "Pop2022" (numerica), "GDPpercapita2022" (numerica)

# %%
cartel1 = pd.read_csv(
    '/content/drive/MyDrive/Data Science Lab/Cartel1.csv', index_col='ISO A3',
    encoding='latin-1')
cartel1
# Out:
#                   Country Continent    RegimeType2022     Pop2022  \
# ISO A3
# AFG           Afghanistan      Asia     Authoritarian  41128771.0
# ALA         Åland Islands    Europa               NaN         NaN
# ALB               Albania    Europa  Flawed democracy   2777689.0
# DZA               Algeria    Africa     Authoritarian  44903225.0
# ASM        American Samoa   Oceania               NaN     44273.0
# ...                   ...       ...               ...         ...
# WLF     Wallis and Futuna   Oceania               NaN         NaN
# ESH           West Sahara    Africa               NaN         NaN
# YEM                 Yemen      Asia     Authoritarian  33696614.0
# ZMB                Zambia    Africa     Hybrid regime  20017675.0
# ZWE              Zimbabwe    Africa     Authoritarian  16320537.0
#
#              GDP2022  GDPpercapita2022
# ISO A3
# AFG     1.447000e+10        351.821843
# ALA              NaN               NaN
# ALB     1.431979e+10       5155.290860
# DZA     1.796020e+11       3999.757256
# ASM     6.627252e+08      14969.059940
# ...              ...               ...
# WLF              NaN               NaN
# ESH              NaN               NaN
# YEM     2.160616e+10        641.196768
# ZMB     2.618516e+10       1308.101838
# ZWE     2.196367e+10       1345.769082
#
# [251 rows x 6 columns]

# %%
mean_indexes = mean_indexes.merge(
    cartel1[['Continent', 'RegimeType2022', 'Pop2022', 'GDPpercapita2022']],
    how='left', left_index=True, right_index=True)

# %%
# Tavola di incrocio cluster-continente (percentuali per riga)

(pd.crosstab(
    mean_indexes['cluster'], mean_indexes['Continent'], normalize='index')
 .style.background_gradient(axis=None))
# Out:
# <style type="text/css">
# #T_35f85_row0_col0, #T_35f85_row5_col6 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_35f85_row0_col1, #T_35f85_row0_col3, #T_35f85_row0_col4, #T_35f85_row0_col6, #T_35f85_row1_col1, #T_35f85_row1_col4, #T_35f85_row1_col6, #T_35f85_row2_col0, #T_35f85_row2_col1, #T_35f85_row2_col3, #T_35f85_row2_col4, #T_35f85_row2_col5, #T_35f85_row2_col6, #T_35f85_row3_col0, #T_35f85_row3_col3, #T_35f85_row3_col6, #T_35f85_row4_col0, #T_35f85_row4_col1, #T_35f85_row4_col3, #T_35f85_row4_col5, #T_35f85_row4_col6, #T_35f85_row5_col0, #T_35f85_row5_col2, #T_35f85_row5_col3, #T_35f85_row5_col5, #T_35f85_row6_col0, #T_35f85_row6_col2, #T_35f85_row6_col3, #T_35f85_row6_col4, #T_35f85_row6_col5, #T_35f85_row6_col6, #T_35f85_row7_col0, #T_35f85_row7_col2, #T_35f85_row7_col3, #T_35f85_row7_col6, #T_35f85_row8_col1, #T_35f85_row8_col3, #T_35f85_row8_col4, #T_35f85_row8_col5, #T_35f85_row8_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_35f85_row0_col2 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_35f85_row0_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_35f85_row1_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_35f85_row1_col2 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_35f85_row1_col3, #T_35f85_row1_col5 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_35f85_row2_col2, #T_35f85_row6_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_35f85_row3_col1, #T_35f85_row3_col2, #T_35f85_row3_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_35f85_row3_col5 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_35f85_row4_col2 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_35f85_row4_col4 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_35f85_row5_col1, #T_35f85_row7_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_35f85_row5_col4 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_35f85_row7_col4 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_35f85_row7_col5 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_35f85_row8_col0 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_35f85_row8_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# </style>
# <table id="T_35f85" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Continent</th>
#       <th id="T_35f85_level0_col0" class="col_heading level0 col0" >Africa</th>
#       <th id="T_35f85_level0_col1" class="col_heading level0 col1" >America</th>
#       <th id="T_35f85_level0_col2" class="col_heading level0 col2" >Asia</th>
#       <th id="T_35f85_level0_col3" class="col_heading level0 col3" >Asia-Oceania</th>
#       <th id="T_35f85_level0_col4" class="col_heading level0 col4" >Europa</th>
#       <th id="T_35f85_level0_col5" class="col_heading level0 col5" >Europa-Asia</th>
#       <th id="T_35f85_level0_col6" class="col_heading level0 col6" >Oceania</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35f85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35f85_row0_col0" class="data row0 col0" >0.222222</td>
#       <td id="T_35f85_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_35f85_row0_col2" class="data row0 col2" >0.666667</td>
#       <td id="T_35f85_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_35f85_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_35f85_row0_col5" class="data row0 col5" >0.111111</td>
#       <td id="T_35f85_row0_col6" class="data row0 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35f85_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35f85_row1_col0" class="data row1 col0" >0.181818</td>
#       <td id="T_35f85_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_35f85_row1_col2" class="data row1 col2" >0.636364</td>
#       <td id="T_35f85_row1_col3" class="data row1 col3" >0.090909</td>
#       <td id="T_35f85_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_35f85_row1_col5" class="data row1 col5" >0.090909</td>
#       <td id="T_35f85_row1_col6" class="data row1 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35f85_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_35f85_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_35f85_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_35f85_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_35f85_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_35f85_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_35f85_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_35f85_row2_col6" class="data row2 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35f85_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35f85_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_35f85_row3_col1" class="data row3 col1" >0.285714</td>
#       <td id="T_35f85_row3_col2" class="data row3 col2" >0.285714</td>
#       <td id="T_35f85_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_35f85_row3_col4" class="data row3 col4" >0.285714</td>
#       <td id="T_35f85_row3_col5" class="data row3 col5" >0.142857</td>
#       <td id="T_35f85_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35f85_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35f85_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_35f85_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_35f85_row4_col2" class="data row4 col2" >0.750000</td>
#       <td id="T_35f85_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_35f85_row4_col4" class="data row4 col4" >0.250000</td>
#       <td id="T_35f85_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_35f85_row4_col6" class="data row4 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35f85_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_35f85_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_35f85_row5_col1" class="data row5 col1" >0.333333</td>
#       <td id="T_35f85_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_35f85_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_35f85_row5_col4" class="data row5 col4" >0.444444</td>
#       <td id="T_35f85_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_35f85_row5_col6" class="data row5 col6" >0.222222</td>
#     </tr>
#     <tr>
#       <th id="T_35f85_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_35f85_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_35f85_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_35f85_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_35f85_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_35f85_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_35f85_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_35f85_row6_col6" class="data row6 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35f85_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_35f85_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_35f85_row7_col1" class="data row7 col1" >0.333333</td>
#       <td id="T_35f85_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_35f85_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_35f85_row7_col4" class="data row7 col4" >0.500000</td>
#       <td id="T_35f85_row7_col5" class="data row7 col5" >0.166667</td>
#       <td id="T_35f85_row7_col6" class="data row7 col6" >0.000000</td>
#     </tr>

# %%
# Tavola di incrocio cluster-regime (percentuali per riga)

(pd.crosstab(
    mean_indexes['cluster'], mean_indexes['RegimeType2022'], normalize='index')
 .style.background_gradient(axis=None))
# Out:
# <style type="text/css">
# #T_e85a9_row0_col0 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_e85a9_row0_col1, #T_e85a9_row0_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_e85a9_row0_col2, #T_e85a9_row1_col2, #T_e85a9_row2_col1, #T_e85a9_row3_col0, #T_e85a9_row3_col3, #T_e85a9_row4_col3, #T_e85a9_row5_col0, #T_e85a9_row5_col3, #T_e85a9_row6_col2, #T_e85a9_row7_col2, #T_e85a9_row8_col1, #T_e85a9_row8_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e85a9_row1_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_e85a9_row1_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_e85a9_row1_col3 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_e85a9_row2_col0, #T_e85a9_row2_col3, #T_e85a9_row4_col0, #T_e85a9_row4_col2, #T_e85a9_row6_col0, #T_e85a9_row8_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_e85a9_row2_col2, #T_e85a9_row4_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_e85a9_row3_col1 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_e85a9_row3_col2 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_e85a9_row5_col1, #T_e85a9_row6_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_e85a9_row5_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e85a9_row6_col3 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_e85a9_row7_col0, #T_e85a9_row7_col3 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_e85a9_row7_col1 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_e85a9_row8_col0 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e85a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >RegimeType2022</th>
#       <th id="T_e85a9_level0_col0" class="col_heading level0 col0" >Authoritarian</th>
#       <th id="T_e85a9_level0_col1" class="col_heading level0 col1" >Flawed democracy</th>
#       <th id="T_e85a9_level0_col2" class="col_heading level0 col2" >Full democracy</th>
#       <th id="T_e85a9_level0_col3" class="col_heading level0 col3" >Hybrid regime</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e85a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e85a9_row0_col0" class="data row0 col0" >0.555556</td>
#       <td id="T_e85a9_row0_col1" class="data row0 col1" >0.222222</td>
#       <td id="T_e85a9_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_e85a9_row0_col3" class="data row0 col3" >0.222222</td>
#     </tr>
#     <tr>
#       <th id="T_e85a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e85a9_row1_col0" class="data row1 col0" >0.454545</td>
#       <td id="T_e85a9_row1_col1" class="data row1 col1" >0.181818</td>
#       <td id="T_e85a9_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_e85a9_row1_col3" class="data row1 col3" >0.363636</td>
#     </tr>
#     <tr>
#       <th id="T_e85a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e85a9_row2_col0" class="data row2 col0" >0.250000</td>
#       <td id="T_e85a9_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_e85a9_row2_col2" class="data row2 col2" >0.500000</td>
#       <td id="T_e85a9_row2_col3" class="data row2 col3" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_e85a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e85a9_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_e85a9_row3_col1" class="data row3 col1" >0.857143</td>
#       <td id="T_e85a9_row3_col2" class="data row3 col2" >0.142857</td>
#       <td id="T_e85a9_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e85a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e85a9_row4_col0" class="data row4 col0" >0.250000</td>
#       <td id="T_e85a9_row4_col1" class="data row4 col1" >0.500000</td>
#       <td id="T_e85a9_row4_col2" class="data row4 col2" >0.250000</td>
#       <td id="T_e85a9_row4_col3" class="data row4 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e85a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e85a9_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_e85a9_row5_col1" class="data row5 col1" >0.125000</td>
#       <td id="T_e85a9_row5_col2" class="data row5 col2" >0.875000</td>
#       <td id="T_e85a9_row5_col3" class="data row5 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e85a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e85a9_row6_col0" class="data row6 col0" >0.250000</td>
#       <td id="T_e85a9_row6_col1" class="data row6 col1" >0.125000</td>
#       <td id="T_e85a9_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_e85a9_row6_col3" class="data row6 col3" >0.625000</td>
#     </tr>
#     <tr>
#       <th id="T_e85a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e85a9_row7_col0" class="data row7 col0" >0.166667</td>
#       <td id="T_e85a9_row7_col1" class="data row7 col1" >0.666667</td>
#       <td id="T_e85a9_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_e85a9_row7_col3" class="data row7 col3" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_e85a9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e85a9_row8_col0" class="data row8 col0" >0.750000</td>
#       <td id="T_e85a9_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_e85a9_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_e85a9_row8_col3" class="data row8 col3" >0.250000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Medie per cluster ("cluster_indexes")

cluster_indexes = (
    mean_indexes.drop(labels=['Continent', 'RegimeType2022'], axis=1)
    .groupby(by='cluster').mean())
cluster_indexes
# Out:
#          DEFIANCE  DISBELIEF  RELATIVISM  SCEPTICISM  AUTONOMY  EQUALITY  \
# cluster
# 0        0.163085   0.282185    0.597601    0.373409  0.430839  0.458878
# 1        0.162937   0.212518    0.314677    0.364840  0.398684  0.395307
# 2        0.445530   0.712886    0.308243    0.356639  0.616094  0.594021
# 3        0.244928   0.339105    0.265483    0.442484  0.435682  0.646274
# 4        0.320353   0.686117    0.682059    0.425078  0.503110  0.521942
# 5        0.293357   0.658122    0.326574    0.387860  0.552629  0.799177
# 6        0.131520   0.312446    0.410779    0.652799  0.316528  0.631369
# 7        0.281742   0.461671    0.514101    0.543959  0.415736  0.600196
# 8        0.110587   0.174375    0.145709    0.462956  0.308882  0.526449
#
#            CHOICE     VOICE       Pop2022  GDPpercapita2022
# cluster
# 0        0.262027  0.332962  3.957682e+07       4939.699398
# 1        0.143516  0.310653  2.342321e+08       3799.424117
# 2        0.405638  0.316639  3.921351e+08      30739.601920
# 3        0.357314  0.381716  4.665639e+07      23856.203933
# 4        0.441923  0.331751  4.097136e+07      15465.466086
# 5        0.684732  0.510514  6.392445e+07      45674.772272
# 6        0.293922  0.415032  3.703260e+07       6983.441132
# 7        0.429600  0.354488  4.336195e+07      10960.562413
# 8        0.151799  0.242403  2.996341e+07       5301.101682

# %%
# Confronti cluster-popolazione e cluster-ricchezza

cluster_indexes[['Pop2022', 'GDPpercapita2022']].plot(kind='bar', subplots=True)
plt.tight_layout()

# %% [markdown]
# # Medie per cluster ("cluster_indexes") tra 0 e 1, per valutare la diversa composizione (importanza) degli indici nei cluster

# %%
cluster_indexes.drop(
    labels=['Pop2022', 'GDPpercapita2022'], axis=1, inplace=True)
cluster_indexes.style.background_gradient(
    cmap='RdBu', axis=None, vmin=0, vmax=1.014)
# Out:
# <style type="text/css">
# #T_0b76d_row0_col0, #T_0b76d_row1_col0 {
#   background-color: #c84440;
#   color: #f1f1f1;
# }
# #T_0b76d_row0_col1, #T_0b76d_row7_col0 {
#   background-color: #ee9677;
#   color: #000000;
# }
# #T_0b76d_row0_col2 {
#   background-color: #d5e7f1;
#   color: #000000;
# }
# #T_0b76d_row0_col3 {
#   background-color: #facab1;
#   color: #000000;
# }
# #T_0b76d_row0_col4, #T_0b76d_row7_col6 {
#   background-color: #fce2d2;
#   color: #000000;
# }
# #T_0b76d_row0_col5 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_0b76d_row0_col6 {
#   background-color: #e8896c;
#   color: #f1f1f1;
# }
# #T_0b76d_row0_col7 {
#   background-color: #f7b596;
#   color: #000000;
# }
# #T_0b76d_row1_col1 {
#   background-color: #d86551;
#   color: #f1f1f1;
# }
# #T_0b76d_row1_col2, #T_0b76d_row2_col7, #T_0b76d_row6_col4 {
#   background-color: #f5aa89;
#   color: #000000;
# }
# #T_0b76d_row1_col3 {
#   background-color: #f9c6ac;
#   color: #000000;
# }
# #T_0b76d_row1_col4 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_0b76d_row1_col5 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_0b76d_row1_col6, #T_0b76d_row8_col2 {
#   background-color: #c13639;
#   color: #f1f1f1;
# }
# #T_0b76d_row1_col7, #T_0b76d_row6_col1 {
#   background-color: #f5a886;
#   color: #000000;
# }
# #T_0b76d_row2_col0 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_0b76d_row2_col1 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# #T_0b76d_row2_col2, #T_0b76d_row8_col4 {
#   background-color: #f4a683;
#   color: #000000;
# }
# #T_0b76d_row2_col3, #T_0b76d_row3_col6 {
#   background-color: #f9c2a7;
#   color: #000000;
# }
# #T_0b76d_row2_col4 {
#   background-color: #cce2ef;
#   color: #000000;
# }
# #T_0b76d_row2_col5 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_0b76d_row2_col6 {
#   background-color: #fddbc7;
#   color: #000000;
# }
# #T_0b76d_row3_col0, #T_0b76d_row8_col7 {
#   background-color: #e27b62;
#   color: #f1f1f1;
# }
# #T_0b76d_row3_col1 {
#   background-color: #f7b799;
#   color: #000000;
# }
# #T_0b76d_row3_col2 {
#   background-color: #e98b6e;
#   color: #f1f1f1;
# }
# #T_0b76d_row3_col3, #T_0b76d_row4_col6 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_0b76d_row3_col4 {
#   background-color: #fbe3d4;
#   color: #000000;
# }
# #T_0b76d_row3_col5 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_0b76d_row3_col7 {
#   background-color: #fbceb7;
#   color: #000000;
# }
# #T_0b76d_row4_col0 {
#   background-color: #f5ac8b;
#   color: #000000;
# }
# #T_0b76d_row4_col1 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_0b76d_row4_col2, #T_0b76d_row5_col6 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_0b76d_row4_col3 {
#   background-color: #fce0d0;
#   color: #000000;
# }
# #T_0b76d_row4_col4 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_0b76d_row4_col5 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_0b76d_row4_col7 {
#   background-color: #f6b394;
#   color: #000000;
# }
# #T_0b76d_row5_col0, #T_0b76d_row6_col6 {
#   background-color: #f19e7d;
#   color: #000000;
# }
# #T_0b76d_row5_col1 {
#   background-color: #b1d5e7;
#   color: #000000;
# }
# #T_0b76d_row5_col2 {
#   background-color: #f6b191;
#   color: #000000;
# }
# #T_0b76d_row5_col3 {
#   background-color: #fbd0b9;
#   color: #000000;
# }
# #T_0b76d_row5_col4 {
#   background-color: #e6eff4;
#   color: #000000;
# }
# #T_0b76d_row5_col5 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_0b76d_row5_col7 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_0b76d_row6_col0 {
#   background-color: #bd2d35;
#   color: #f1f1f1;
# }
# #T_0b76d_row6_col2 {
#   background-color: #fddcc9;
#   color: #000000;
# }
# #T_0b76d_row6_col3 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_0b76d_row6_col5 {
#   background-color: #c2ddec;
#   color: #000000;
# }
# #T_0b76d_row6_col7, #T_0b76d_row7_col4 {
#   background-color: #fdddcb;
#   color: #000000;
# }
# #T_0b76d_row7_col1, #T_0b76d_row8_col3 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_0b76d_row7_col2 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_0b76d_row7_col3 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_0b76d_row7_col5 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_0b76d_row7_col7 {
#   background-color: #f8bfa4;
#   color: #000000;
# }
# #T_0b76d_row8_col0 {
#   background-color: #b41c2d;
#   color: #f1f1f1;
# }
# #T_0b76d_row8_col1 {
#   background-color: #cc4c44;
#   color: #f1f1f1;
# }
# #T_0b76d_row8_col5 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_0b76d_row8_col6 {
#   background-color: #c43b3c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0b76d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b76d_level0_col0" class="col_heading level0 col0" >DEFIANCE</th>
#       <th id="T_0b76d_level0_col1" class="col_heading level0 col1" >DISBELIEF</th>
#       <th id="T_0b76d_level0_col2" class="col_heading level0 col2" >RELATIVISM</th>
#       <th id="T_0b76d_level0_col3" class="col_heading level0 col3" >SCEPTICISM</th>
#       <th id="T_0b76d_level0_col4" class="col_heading level0 col4" >AUTONOMY</th>
#       <th id="T_0b76d_level0_col5" class="col_heading level0 col5" >EQUALITY</th>
#       <th id="T_0b76d_level0_col6" class="col_heading level0 col6" >CHOICE</th>
#       <th id="T_0b76d_level0_col7" class="col_heading level0 col7" >VOICE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b76d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b76d_row0_col0" class="data row0 col0" >0.163085</td>
#       <td id="T_0b76d_row0_col1" class="data row0 col1" >0.282185</td>
#       <td id="T_0b76d_row0_col2" class="data row0 col2" >0.597601</td>
#       <td id="T_0b76d_row0_col3" class="data row0 col3" >0.373409</td>
#       <td id="T_0b76d_row0_col4" class="data row0 col4" >0.430839</td>
#       <td id="T_0b76d_row0_col5" class="data row0 col5" >0.458878</td>
#       <td id="T_0b76d_row0_col6" class="data row0 col6" >0.262027</td>
#       <td id="T_0b76d_row0_col7" class="data row0 col7" >0.332962</td>
#     </tr>
#     <tr>
#       <th id="T_0b76d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0b76d_row1_col0" class="data row1 col0" >0.162937</td>
#       <td id="T_0b76d_row1_col1" class="data row1 col1" >0.212518</td>
#       <td id="T_0b76d_row1_col2" class="data row1 col2" >0.314677</td>
#       <td id="T_0b76d_row1_col3" class="data row1 col3" >0.364840</td>
#       <td id="T_0b76d_row1_col4" class="data row1 col4" >0.398684</td>
#       <td id="T_0b76d_row1_col5" class="data row1 col5" >0.395307</td>
#       <td id="T_0b76d_row1_col6" class="data row1 col6" >0.143516</td>
#       <td id="T_0b76d_row1_col7" class="data row1 col7" >0.310653</td>
#     </tr>
#     <tr>
#       <th id="T_0b76d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0b76d_row2_col0" class="data row2 col0" >0.445530</td>
#       <td id="T_0b76d_row2_col1" class="data row2 col1" >0.712886</td>
#       <td id="T_0b76d_row2_col2" class="data row2 col2" >0.308243</td>
#       <td id="T_0b76d_row2_col3" class="data row2 col3" >0.356639</td>
#       <td id="T_0b76d_row2_col4" class="data row2 col4" >0.616094</td>
#       <td id="T_0b76d_row2_col5" class="data row2 col5" >0.594021</td>
#       <td id="T_0b76d_row2_col6" class="data row2 col6" >0.405638</td>
#       <td id="T_0b76d_row2_col7" class="data row2 col7" >0.316639</td>
#     </tr>
#     <tr>
#       <th id="T_0b76d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0b76d_row3_col0" class="data row3 col0" >0.244928</td>
#       <td id="T_0b76d_row3_col1" class="data row3 col1" >0.339105</td>
#       <td id="T_0b76d_row3_col2" class="data row3 col2" >0.265483</td>
#       <td id="T_0b76d_row3_col3" class="data row3 col3" >0.442484</td>
#       <td id="T_0b76d_row3_col4" class="data row3 col4" >0.435682</td>
#       <td id="T_0b76d_row3_col5" class="data row3 col5" >0

# %% [markdown]
# # Multidimensional scaling

# %%
s = (
    indexes.merge(
        mean_indexes['cluster'], left_on='B_COUNTRY_ALPHA', right_index=True)
    .value_counts('cluster', sort=False))

# %%
c = [
    '#c44e52', '#64443c', '#8c8c8c', '#55a868', '#64b5cd', '#da8bc3', '#dd8452',
    '#ccb974', '#8172b3']
mds = MDS(
    n_init=9, max_iter=3000, verbose=1, eps=1e-9, normalized_stress='auto')
mds = mds.fit_transform(cluster_indexes)
plt.scatter(mds[:, 0], mds[:, 1], s=s/10, c=c, alpha=.5)
for i in range(9):
    plt.annotate(i, (mds[i, 0], mds[i, 1]))
# Out:
# breaking at iteration 96 with stress 0.16611026594909406
# breaking at iteration 165 with stress 0.16612617777030744
# breaking at iteration 240 with stress 0.3744246106647012
# breaking at iteration 49 with stress 0.24680237943444433
# breaking at iteration 53 with stress 0.2809450908893929
# breaking at iteration 144 with stress 0.16611026542024288
# breaking at iteration 134 with stress 0.24674729866601766
# breaking at iteration 132 with stress 0.16612677195771963
# breaking at iteration 248 with stress 0.21254628171256978

# %%
nmds = MDS(
    metric=False, n_init=9, max_iter=3000, verbose=1, eps=1e-12,
    normalized_stress='auto')
nmds = nmds.fit_transform(cluster_indexes)
plt.scatter(nmds[:, 0], nmds[:, 1], s=s/10, c=c, alpha=.5)
for i in range(9):
    plt.annotate(i, (nmds[i, 0], nmds[i, 1]))
# Out:
# breaking at iteration 5 with stress 0.2712479538043383
# breaking at iteration 456 with stress 0.03426561560642622
# breaking at iteration 6 with stress 0.23189368654396536
# breaking at iteration 4 with stress 0.2442907855683979
# breaking at iteration 191 with stress 0.03570762262645921
# breaking at iteration 4 with stress 0.2625600776362369
# breaking at iteration 177 with stress 0.050020601643777675
# breaking at iteration 556 with stress 0.08392382608591999
# breaking at iteration 35 with stress 0.2018941491860361

# %%
mean_indexes.iloc[:, 0:9].to_csv(
    path_or_buf='/content/drive/MyDrive/Data Science Lab/mean_indexes.csv')

# %% [markdown]
# # Distribuzione geografica dei cluster

# %%
import geopandas as gpd
from matplotlib.colors import ListedColormap

# %%
colors = [
    '#c44e52', '#64443c', '#8c8c8c', '#55a868', '#64b5cd', '#da8bc3', '#dd8452',
    '#ccb974', '#8172b3']
cmap = ListedColormap(colors)

# %%
shapefile_path = '/content/drive/MyDrive/Data Science Lab/data science shp/ne_110m_admin_0_countries.shp'
world = gpd.read_file(shapefile_path)
# Unisci i dati dei cluster con i dati geografici
world = world.merge(mean_indexes.iloc[:, 0:9], how='left', left_on='ISO_A3_EH', right_on='B_COUNTRY_ALPHA')

# Crea una mappa con i cluster
fig, ax = plt.subplots(1, 1, figsize=(20, 15))
world.plot(column='cluster', ax=ax, legend=True, cmap=cmap, edgecolor='black')
world.boundary.plot(ax=ax, color='black', linewidth=.6)
plt.title('Mappa dei Cluster per Paese')
plt.show()

# %% [markdown]
# # UMAP

# %%
# %pip install pandas umap-learn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Collecting umap-learn
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.3.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.9 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.13 umap-learn-0.5.6

# %%
import umap
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.metrics import silhouette_score

# %%
umap_model = umap.UMAP(n_neighbors=10, metric='euclidean', n_components=2, random_state=42)
umap_embedding = umap_model.fit_transform(mean_indexes.iloc[:, 0:8])
mean_indexes['umap1'] = umap_embedding[:, 0]
mean_indexes['umap2'] = umap_embedding[:, 1]
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
range_n_clusters = list(range(2, 11))

results={}

for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(umap_embedding)

    silhouette_avg = silhouette_score(umap_embedding, cluster_labels)
    results[n_clusters]=silhouette_avg

results
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# {2: 0.5788041,
#  3: 0.4834513,
#  4: 0.5532434,
#  5: 0.5781947,
#  6: 0.5895384,
#  7: 0.5816944,
#  8: 0.56231195,
#  9: 0.5665154,
#  10: 0.5317802}

# %%
kmeans = KMeans(n_clusters=7, random_state=42)
mean_indexes['kcluster'] = kmeans.fit_predict(umap_embedding)
mean_indexes
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                  DEFIANCE  DISBELIEF  RELATIVISM  SCEPTICISM  AUTONOMY  \
# B_COUNTRY_ALPHA
# AND              0.317477   0.667209    0.219285    0.448804  0.470808
# ARG              0.232448   0.465384    0.387223    0.646421  0.422446
# ARM              0.117089   0.315006    0.116716    0.518320  0.354184
# AUS              0.262710   0.669868    0.309231    0.339224  0.565234
# BGD              0.084851   0.134763    0.364076    0.357076  0.425847
# ...                   ...        ...         ...         ...       ...
# USA              0.292283   0.495941    0.419456    0.385974  0.565681
# UZB              0.106755   0.390307    0.476516    0.221915  0.538188
# VEN              0.133942   0.408977    0.396919    0.735165  0.277871
# VNM              0.135717   0.638662    0.653738    0.267428  0.376335
# ZWE              0.124523   0.102842    0.212187    0.490761  0.276766
#
#                  EQUALITY    CHOICE     VOICE  cluster Continent  \
# B_COUNTRY_ALPHA
# AND              0.821144  0.716493  0.497649        5    Europa
# ARG              0.701435  0.486628  0.371500        7   America
# ARM              0.540881  0.167118  0.160574        8      Asia
# AUS              0.818340  0.693670  0.464546        5   Oceania
# BGD              0.386657  0.107031  0.299406        1      Asia
# ...                   ...       ...       ...      ...       ...
# USA              0.723078  0.562686  0.459695        5   America
# UZB              0.346207  0.217257  0.400038        0      Asia
# VEN              0.658154  0.353688  0.349197        6   America
# VNM              0.496048  0.446349  0.310514        4      Asia
# ZWE              0.574300  0.119331  0.286254        8    Africa
#
#                    RegimeType2022      Pop2022  GDPpercapita2022     umap1  \
# B_COUNTRY_ALPHA
# AND                           NaN      79824.0      39447.538250  9.218071
# ARG              Flawed democracy   46234830.0      12940.741860  5.416199
# ARM                 Hybrid regime    2780469.0       5116.205756  5.191724
# AUS                Full democracy   26005540.0      60993.542150  9.077559
# BGD                 Hybrid regime  171186372.0       1784.739033  4.193383
# ...                           ...          ...               ...       ...
# USA              Flawed democracy  333287557.0      62789.022750  8.854640
# UZB                 Authoritarian   35648100.0       3473.368847  3.352051
# VEN                 Authoritarian   28301696.0      17043.477540  4.184013
# VNM                 Authoritarian   98186856.0       3655.458731  6.091177
# ZWE                 Authoritarian   16320537.0       1345.769082  5.534007
#
#                      umap2  kcluster
# B_COUNTRY_ALPHA
# AND              15.213971         1
# ARG              12.440111         4
# ARM               8.818723         3
# AUS              15.246683         1
# BGD               8.509618         3
# ...                    ...       ...
# USA              14.901771         1
# UZB               9.417939         0
# VEN              11.969147         6
# VNM              13.360635         4
# ZWE               8.389576         3
#
# [63 rows x 16 columns]

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))

sns.scatterplot(
    x='umap1', y='umap2',
    hue='kcluster',
    palette='viridis',
    data=mean_indexes,
    legend="full",
    alpha=0.7
)
plt.title('UMAP Clustering')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()

# %%
silhouette_score(umap_embedding, mean_indexes['kcluster'])
# Out:
# 0.5816944

# %%
clusters_grouped = mean_indexes.groupby('kcluster')
for cluster, group in clusters_grouped:
    print(f'\nCluster {cluster}:')
    print(group.index.tolist())
# Out:
# Cluster 0:
# ['IRQ', 'KAZ', 'KEN', 'LBN', 'MAR', 'MYS', 'PHL', 'TJK', 'UZB']
#
# Cluster 1:
# ['AND', 'AUS', 'CAN', 'DEU', 'GBR', 'NLD', 'NZL', 'URY', 'USA']
#
# Cluster 2:
# ['CHN', 'HKG', 'JPN', 'KOR', 'TWN']
#
# Cluster 3:
# ['ARM', 'BGD', 'ETH', 'IDN', 'IND', 'IRN', 'JOR', 'KGZ', 'LBY', 'MDV', 'MMR', 'NGA', 'PAK', 'TUN', 'TUR', 'ZWE']
#
# Cluster 4:
# ['ARG', 'CHL', 'CZE', 'MNG', 'RUS', 'SRB', 'SVK', 'THA', 'UKR', 'VNM']
#
# Cluster 5:
# ['BRA', 'CYP', 'GRC', 'PRI', 'ROU', 'SGP']
#
# Cluster 6:
# ['BOL', 'COL', 'ECU', 'GTM', 'MEX', 'NIC', 'PER', 'VEN']

# %% [markdown]
# # Approfondimento dei cluster gerarchici

# %%
mean_df1 = df1.groupby(by='B_COUNTRY_ALPHA').mean()
mean_df1
# Out:
#                  I_AUTHORITY  I_NATIONALISM  I_DEVOUT  DEFIANCE  I_RELIGIMP  \
# B_COUNTRY_ALPHA
# AND                 0.304791       0.181706  0.343381  0.317477    0.654602
# ARG                 0.207647       0.176340  0.289450  0.232448    0.465017
# ARM                 0.117201       0.067069  0.151776  0.117089    0.132584
# AUS                 0.265734       0.159375  0.346853  0.262710    0.630568
# BGD                 0.128843       0.061742  0.052980  0.084851    0.022928
# ...                      ...            ...       ...       ...         ...
# USA                 0.283736       0.279576  0.309150  0.292283    0.432432
# UZB                 0.203892       0.059576  0.045352  0.106755    0.234635
# VEN                 0.127731       0.099162  0.173160  0.133942    0.296118
# VNM                 0.086003       0.152234  0.168912  0.135717    0.543727
# ZWE                 0.086035       0.198612  0.087034  0.124523    0.047020
#
#                  I_RELIGBEL  I_RELIGPRAC  DISBELIEF   I_NORM1   I_NORM2  ...  \
# B_COUNTRY_ALPHA                                                          ...
# AND                0.551478     0.795748   0.667209  0.287462  0.239796  ...
# ARG                0.273908     0.629195   0.465384  0.516892  0.361080  ...
# ARM                0.163354     0.645064   0.315006  0.115318  0.156947  ...
# AUS                0.616887     0.760757   0.669868  0.426598  0.327972  ...
# BGD                0.020246     0.349301   0.134763  0.403928  0.362938  ...
# ...                     ...          ...        ...       ...       ...  ...
# USA                0.446952     0.606575   0.495941  0.586166  0.381272  ...
# UZB                0.525166     0.411938   0.390307  0.736372  0.461264  ...
# VEN                0.434454     0.496359   0.408977  0.475630  0.375630  ...
# VNM                0.693929     0.678330   0.638662  0.709949  0.619730  ...
# ZWE                0.037344     0.222682   0.102842  0.229685  0.202815  ...
#
#                  I_WOMEDU  EQUALITY  I_HOMOLIB  I_ABORTLIB  I_DIVORLIB  \
# B_COUNTRY_ALPHA
# AND              0.847829  0.821144   0.779823    0.565543    0.805215
# ARG              0.751196  0.701435   0.561795    0.300402    0.614453
# ARM              0.711496  0.540881   0.042073    0.165359    0.293452
# AUS              0.879788  0.818340   0.713081    0.621941    0.750865
# BGD              0.520357  0.386657   0.077711    0.113768    0.129614
# ...                   ...       ...        ...         ...         ...
# USA              0.773680  0.723078   0.613053    0.453974    0.623232
# UZB              0.407885  0.346207        NaN    0.211861    0.267219
# VEN              0.687790  0.658154   0.353408    0.204668    0.502988
# VNM              0.578836  0.496048   0.515833    0.353476    0.469740
# ZWE              0.723694  0.574300   0.080129    0.085980    0.191107
#
#                    CHOICE  I_VOICE1  I_VOICE2  I_VOI2_00     VOICE
# B_COUNTRY_ALPHA
# AND              0.716493  0.460890  0.535204   0.498703  0.497649
# ARG              0.486628  0.344088  0.398618   0.370239  0.371500
# ARM              0.167118  0.248906  0.066144   0.157135  0.160574
# AUS              0.693670  0.521589  0.407429   0.463869  0.464546
# BGD              0.107031  0.371657  0.227156   0.299406  0.299406
# ...                   ...       ...       ...        ...       ...
# USA              0.562686  0.554395  0.365238   0.459204  0.459695
# UZB              0.217257  0.392302  0.408641   0.401686  0.400038
# VEN              0.353688  0.359739  0.338655   0.349197  0.349197
# VNM              0.446349  0.420354  0.200675   0.310514  0.310514
# ZWE              0.119331  0.318357  0.253333   0.285844  0.286254
#
# [63 rows x 32 columns]

# %%
mean_df1['cluster'] = clustering.labels_
mean_df1
# Out:
#                  I_AUTHORITY  I_NATIONALISM  I_DEVOUT  DEFIANCE  I_RELIGIMP  \
# B_COUNTRY_ALPHA
# AND                 0.304791       0.181706  0.343381  0.317477    0.654602
# ARG                 0.207647       0.176340  0.289450  0.232448    0.465017
# ARM                 0.117201       0.067069  0.151776  0.117089    0.132584
# AUS                 0.265734       0.159375  0.346853  0.262710    0.630568
# BGD                 0.128843       0.061742  0.052980  0.084851    0.022928
# ...                      ...            ...       ...       ...         ...
# USA                 0.283736       0.279576  0.309150  0.292283    0.432432
# UZB                 0.203892       0.059576  0.045352  0.106755    0.234635
# VEN                 0.127731       0.099162  0.173160  0.133942    0.296118
# VNM                 0.086003       0.152234  0.168912  0.135717    0.543727
# ZWE                 0.086035       0.198612  0.087034  0.124523    0.047020
#
#                  I_RELIGBEL  I_RELIGPRAC  DISBELIEF   I_NORM1   I_NORM2  ...  \
# B_COUNTRY_ALPHA                                                          ...
# AND                0.551478     0.795748   0.667209  0.287462  0.239796  ...
# ARG                0.273908     0.629195   0.465384  0.516892  0.361080  ...
# ARM                0.163354     0.645064   0.315006  0.115318  0.156947  ...
# AUS                0.616887     0.760757   0.669868  0.426598  0.327972  ...
# BGD                0.020246     0.349301   0.134763  0.403928  0.362938  ...
# ...                     ...          ...        ...       ...       ...  ...
# USA                0.446952     0.606575   0.495941  0.586166  0.381272  ...
# UZB                0.525166     0.411938   0.390307  0.736372  0.461264  ...
# VEN                0.434454     0.496359   0.408977  0.475630  0.375630  ...
# VNM                0.693929     0.678330   0.638662  0.709949  0.619730  ...
# ZWE                0.037344     0.222682   0.102842  0.229685  0.202815  ...
#
#                  EQUALITY  I_HOMOLIB  I_ABORTLIB  I_DIVORLIB    CHOICE  \
# B_COUNTRY_ALPHA
# AND              0.821144   0.779823    0.565543    0.805215  0.716493
# ARG              0.701435   0.561795    0.300402    0.614453  0.486628
# ARM              0.540881   0.042073    0.165359    0.293452  0.167118
# AUS              0.818340   0.713081    0.621941    0.750865  0.693670
# BGD              0.386657   0.077711    0.113768    0.129614  0.107031
# ...                   ...        ...         ...         ...       ...
# USA              0.723078   0.613053    0.453974    0.623232  0.562686
# UZB              0.346207        NaN    0.211861    0.267219  0.217257
# VEN              0.658154   0.353408    0.204668    0.502988  0.353688
# VNM              0.496048   0.515833    0.353476    0.469740  0.446349
# ZWE              0.574300   0.080129    0.085980    0.191107  0.119331
#
#                  I_VOICE1  I_VOICE2  I_VOI2_00     VOICE  cluster
# B_COUNTRY_ALPHA
# AND              0.460890  0.535204   0.498703  0.497649        5
# ARG              0.344088  0.398618   0.370239  0.371500        7
# ARM              0.248906  0.066144   0.157135  0.160574        8
# AUS              0.521589  0.407429   0.463869  0.464546        5
# BGD              0.371657  0.227156   0.299406  0.299406        1
# ...                   ...       ...        ...       ...      ...
# USA              0.554395  0.365238   0.459204  0.459695        5
# UZB              0.392302  0.408641   0.401686  0.400038        0
# VEN              0.359739  0.338655   0.349197  0.349197        6
# VNM              0.420354  0.200675   0.310514  0.310514        4
# ZWE              0.318357  0.253333   0.285844  0.286254        8
#
# [63 rows x 33 columns]

# %%
mean_df1.groupby(by='cluster').mean().iloc[:, 0:3]
# Out:
#          I_AUTHORITY  I_NATIONALISM  I_DEVOUT
# cluster
# 0           0.207676       0.166568  0.111496
# 1           0.296221       0.092374  0.093994
# 2           0.634494       0.319040  0.370220
# 3           0.330116       0.174859  0.219289
# 4           0.373332       0.283538  0.300803
# 5           0.269082       0.223640  0.352462
# 6           0.127950       0.099619  0.162851
# 7           0.287468       0.246661  0.289663
# 8           0.142388       0.105285  0.078224
